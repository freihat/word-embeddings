# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
word_counts = Counter(words)

# %%
## Your code here
from math import sqrt 
P = lambda x: 1 - sqrt(1/x)
freq_dict = {word: P(frequency) for word, frequency in word_counts.items()}

#sorted_by_value = sorted(freq_dict.items(), key=lambda x: x[1], reverse=True)

train_words_words = [word for word in words if freq_dict[word]<=0.9930117757187348]
# the chosen number is the probability of the word 'american', which is the most frequent word in our
# data which may provide context to nearby words.
train_words = [vocab_to_int[word] for word in train_words_words]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
from random import randint
# Your code here
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = randint(1,window_size)
    train = [ words[idx-n] for n in range(1, (R+1)*(R<=idx) + (idx+1)*(R>idx) ) ]
    target = [ words[idx+n] for n in range(1, (R+1)*(idx+R+1<=len(words)) + (len(words)-idx)*(idx+R+1 > len(words) )) ]       
    return set(target)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None,None], name = 'labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding),minval=-1, maxval=1))
    embed = tf.nn.embedding_lookup(embedding,inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab,n_embedding),stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed,n_sampled,n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-17-6cd0def8ff91>:14: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 6.4456 0.1631 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.3833 0.1631 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.3057 0.1694 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.2914 0.1554 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.1467 0.1563 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 6.0192 0.1572 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 6.0049 0.1566 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.9403 0.1562 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.7043 0.1570 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5156 0.1593 sec/batch
# Nearest to more: russcol, unfalsifiable, friend, agitator, moorcock, ethic, trismegistus, solidifying,
# Nearest to with: meteorologists, modernized, tiberias, recht, intermediate, simplified, plurals, scam,
# Nearest to from: away, ans, iced, maternal, involved, glissando, amphibole, neumann,
# Nearest to will: guerrillas, robot, power, no, sought, speedway, dimensionally, caracas,
# Nearest to by: staubach, food, affiliation, mitzvah, cretans, casino, leibniz, genotype,
# Nearest to american: dodge, montt, slot, ascending, doo, scams, footballer, bushnell,
# Nearest to war: improved, name, add, montrealers, ncv, according, approximate, empire,
# Nearest to it: disgusting, dharmakirti, reuniting, schiavo, obe, preserver, experienced, curried,
# Nearest to accepted: came, canaan, aerial, easing, humanitarian, posted, mubarak, jules,
# Nearest to woman: gandhara, friends, heater, mastered, sleeves, dsv, idriss, dollfu,
# Nearest to scale: pasquale, druidic, albion, neuroleptic, slayer, geckos, diachronic, incubators,
# Nearest to shown: leader, firefighting, indicate, lamentations, conceded, decapitated, hf, sacred,
# Nearest to frac: nascent, recording, lct, sneeze, colorings, ratified, owned, think,
# Nearest to hold: caused, castor, unique, associated, raven, naghten, introduces, restrictive,
# Nearest to construction: hypro, provide, harbors, seebeck, neander, fashion, states, thermonuclear,
# Nearest to notes: kansas, workmen, rockies, carnival, loeb, alanine, willughby, dizziness,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4305 0.1607 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.2939 0.1569 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2162 0.1588 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.0534 0.1577 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.0740 0.1590 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.9772 0.1607 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9186 0.1659 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8369 0.1714 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.8881 0.1569 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8226 0.1577 sec/batch
# Nearest to more: russcol, unfalsifiable, friend, agitator, ethic, moorcock, trismegistus, solidifying,
# Nearest to with: meteorologists, modernized, tiberias, recht, infraction, scam, plurals, inline,
# Nearest to from: iced, ans, away, maternal, neumann, involved, amphibole, glissando,
# Nearest to will: guerrillas, robot, no, ribbons, k, indefinite, slowed, configuring,
# Nearest to by: staubach, food, mitzvah, cretans, affiliation, casino, leibniz, genotype,
# Nearest to american: slot, closely, footballer, doo, dodge, ascending, seats, french,
# Nearest to war: improved, candidates, add, dec, imaginary, governing, approximate, empire,
# Nearest to it: dharmakirti, schiavo, preserver, curried, reuniting, disgusting, ocho, obe,
# Nearest to accepted: aerial, came, reconstruction, canaan, humanitarian, posted, accompany, mubarak,
# Nearest to woman: gandhara, friends, respectively, heater, low, palestine, sleeves, mastered,
# Nearest to scale: covers, pounds, albion, neuroleptic, pasquale, mean, slayer, sox,
# Nearest to shown: indicate, regional, leader, sacred, marriages, firefighting, pull, significance,
# Nearest to frac: recording, owned, think, where, ratified, canaan, refused, contempt,
# Nearest to hold: caused, past, broadway, associated, mentions, unique, usaf, raven,
# Nearest to construction: fashion, provide, thermonuclear, hypro, harbors, x, region, popularity,
# Nearest to notes: kansas, rockies, workmen, carnival, billboard, vastly, shui, systematically,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.7740 0.1627 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.7345 0.1575 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.6274 0.1575 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.7374 0.1687 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.6476 0.1596 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.6786 0.1584 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.6621 0.1578 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.6288 0.1584 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.6675 0.1577 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6306 0.1572 sec/batch
# Nearest to more: russcol, unfalsifiable, friend, agitator, ethic, moorcock, trismegistus, solidifying,
# Nearest to with: meteorologists, modernized, tiberias, recht, scam, infraction, plurals, inline,
# Nearest to from: iced, ans, away, maternal, neumann, involved, amphibole, glissando,
# Nearest to will: guerrillas, no, robot, ribbons, indefinite, configuring, resign, power,
# Nearest to by: staubach, food, mitzvah, cretans, affiliation, casino, genotype, leibniz,
# Nearest to american: dodge, slot, footballer, paramilitary, montt, closely, facto, winthrop,
# Nearest to war: improved, dec, imaginary, charlemagne, military, candidates, approximate, governing,
# Nearest to it: dharmakirti, schiavo, reuniting, curried, ocho, preserver, obe, testimonium,
# Nearest to accepted: aerial, posted, humanitarian, reconstruction, came, canaan, easing, cease,
# Nearest to woman: gandhara, friends, heater, respectively, mastered, scattered, sleeves, dsv,
# Nearest to scale: pounds, covers, pasquale, albion, neuroleptic, slayer, avail, druidic,
# Nearest to shown: indicate, sacred, regional, pull, marriages, natures, leader, hf,
# Nearest to frac: nascent, where, recording, think, computations, temporal, owned, ratified,
# Nearest to hold: caused, past, restrictive, castor, mentions, raven, usaf, auto,
# Nearest to construction: fashion, harbors, watterson, hypro, jurisdictions, ceiling, thermonuclear, extracted,
# Nearest to notes: rockies, workmen, carnival, kansas, systematically, inventions, billboard, vastly,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6257 0.1604 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.5433 0.1577 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.5897 0.1594 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.5676 0.1581 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.5836 0.1614 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.5514 0.1604 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.5770 0.1577 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.5550 0.1678 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.5317 0.1640 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.5275 0.1595 sec/batch
# Nearest to more: russcol, unfalsifiable, friend, agitator, moorcock, ethic, trismegistus, solidifying,
# Nearest to with: meteorologists, tiberias, modernized, recht, infraction, plurals, discovery, inline,
# Nearest to from: iced, away, maternal, ans, neumann, amphibole, pacifists, glissando,
# Nearest to will: no, guerrillas, person, might, robot, even, ribbons, resign,
# Nearest to by: staubach, food, mitzvah, cretans, affiliation, casino, genotype, leibniz,
# Nearest to american: footballer, dodge, french, russian, slot, paramilitary, winthrop, montt,
# Nearest to war: military, charlemagne, germany, candidates, dec, improved, spice, governing,
# Nearest to it: dharmakirti, curried, ocho, schiavo, testimonium, reuniting, disgusting, hugs,
# Nearest to accepted: aerial, posted, humanitarian, reconstruction, came, covenants, accompany, canaan,
# Nearest to woman: gandhara, friends, heater, respectively, dsv, idriss, scattered, mastered,
# Nearest to scale: pounds, covers, druidic, pasquale, slayer, albion, neuroleptic, avail,
# Nearest to shown: indicate, natures, regional, pull, firefighting, marriages, hf, sacred,
# Nearest to frac: where, nascent, think, computations, recording, temporal, dean, adys,
# Nearest to hold: caused, restrictive, past, introduces, mentions, creation, castor, usaf,
# Nearest to construction: fashion, ceiling, frenzy, dearly, harbors, osprey, hypro, firestorm,
# Nearest to notes: rockies, billboard, workmen, kansas, carnival, inventions, systematically, procurement,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.4348 0.1618 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.4243 0.1656 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.5031 0.1608 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.4723 0.1663 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.4942 0.1584 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.4445 0.1577 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.4621 0.1586 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.4207 0.1581 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.4593 0.1578 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.4218 0.1569 sec/batch
# Nearest to more: russcol, unfalsifiable, agitator, friend, moorcock, ethic, trismegistus, barren,
# Nearest to with: meteorologists, tiberias, modernized, recht, vernon, infraction, discovery, scam,
# Nearest to from: iced, maternal, away, ans, amphibole, neumann, pacifists, glissando,
# Nearest to will: guerrillas, no, does, might, ribbons, allow, person, even,
# Nearest to by: staubach, food, mitzvah, cretans, affiliation, casino, genotype, leibniz,
# Nearest to american: footballer, dodge, russian, jason, winthrop, jr, leader, scams,
# Nearest to war: military, gangster, germany, charlemagne, volusia, improved, dominate, governing,
# Nearest to it: dharmakirti, ocho, curried, schiavo, testimonium, disgusting, hugs, reuniting,
# Nearest to accepted: reconstruction, aerial, covenants, humanitarian, canaan, accompany, posted, came,
# Nearest to woman: gandhara, friends, heater, dsv, mastered, father, respectively, idriss,
# Nearest to scale: pounds, albion, druidic, slayer, avail, covers, pasquale, neuroleptic,
# Nearest to shown: indicate, pull, conceded, natures, lamentations, marriages, sacred, hf,
# Nearest to frac: where, infty, nascent, right, above, lct, janssen, adys,
# Nearest to hold: caused, restrictive, past, usaf, castor, sweetness, mentions, introduces,
# Nearest to construction: fashion, ceiling, frenzy, prefect, osprey, dearly, harbors, region,
# Nearest to notes: rockies, billboard, workmen, systematically, carnival, procurement, loeb, inventions,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.4239 0.1619 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.4010 0.1581 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.3276 0.1574 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.4102 0.1601 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.4348 0.1594 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.4060 0.1582 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.4372 0.1585 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.3478 0.1573 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.4031 0.1604 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.3983 0.1612 sec/batch
# Nearest to more: russcol, unfalsifiable, moorcock, agitator, friend, trismegistus, ethic, barren,
# Nearest to with: meteorologists, tiberias, modernized, recht, discovery, vernon, infraction, scam,
# Nearest to from: iced, away, maternal, ans, amphibole, glissando, neumann, pacifists,
# Nearest to will: guerrillas, does, no, ribbons, might, would, you, allow,
# Nearest to by: staubach, food, mitzvah, cretans, genotype, affiliation, casino, subotnick,
# Nearest to american: footballer, dodge, scams, winthrop, jr, paramilitary, sera, bushnell,
# Nearest to war: military, germany, dominate, charlemagne, gangster, volusia, failed, prisoners,
# Nearest to it: dharmakirti, ocho, curried, testimonium, schiavo, hugs, reuniting, disgusting,
# Nearest to accepted: reconstruction, cease, prescriptions, covenants, posted, aerial, accompany, hofstadter,
# Nearest to woman: gandhara, heater, friends, father, mastered, niki, dsv, idriss,
# Nearest to scale: pounds, avail, druidic, diachronic, albion, slayer, covers, neuroleptic,
# Nearest to shown: indicate, pull, natures, conceded, lamentations, blunder, hf, marriages,
# Nearest to frac: infty, right, above, where, lct, janssen, nascent, lustre,
# Nearest to hold: caused, restrictive, past, lind, steffi, ramirez, introduces, mentions,
# Nearest to construction: fashion, ceiling, dearly, osprey, frenzy, prefect, harbors, bemba,
# Nearest to notes: rockies, billboard, loeb, procurement, plotters, workmen, inventions, carnival,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.3663 0.1625 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.4041 0.1596 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.3912 0.1594 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.4050 0.1587 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.2397 0.1584 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.3254 0.1583 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.3260 0.1583 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.3157 0.1585 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.3285 0.1578 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.1950 0.1601 sec/batch
# Nearest to more: russcol, unfalsifiable, moorcock, agitator, ethic, friend, trismegistus, barren,
# Nearest to with: meteorologists, modernized, tiberias, recht, vernon, discovery, infraction, scam,
# Nearest to from: maternal, iced, away, ans, glissando, amphibole, pacifists, neumann,
# Nearest to will: would, does, might, you, guerrillas, allow, no, ribbons,
# Nearest to by: staubach, food, mitzvah, cretans, genotype, affiliation, subotnick, csicop,
# Nearest to american: footballer, jr, jason, jos, dodge, swimmer, filmmaker, canadian,
# Nearest to war: military, germany, ira, dominate, wars, ii, militarism, charlemagne,
# Nearest to it: dharmakirti, curried, testimonium, ocho, schiavo, hugs, obe, reuniting,
# Nearest to accepted: reconstruction, prescriptions, humanitarian, slovenes, cease, hofstadter, covenants, posted,
# Nearest to woman: gandhara, heater, niki, father, friends, hammurabi, idriss, mastered,
# Nearest to scale: pounds, druidic, avail, diachronic, pasquale, albion, neuroleptic, feasible,
# Nearest to shown: indicate, pull, lamentations, conceded, natures, blunder, hf, firefighting,
# Nearest to frac: infty, right, above, psi, lct, where, sum, linear,
# Nearest to hold: caused, restrictive, ramirez, steffi, lind, past, mentions, washed,
# Nearest to construction: fashion, ceiling, bemba, osprey, dearly, homegrown, region, inflectional,
# Nearest to notes: rockies, syntax, inventions, plotters, loeb, billboard, procurement, workmen,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.2209 0.1615 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.2365 0.1593 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.2904 0.1603 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.3728 0.1583 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.3159 0.1587 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.4023 0.1587 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.3727 0.1587 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.2795 0.1616 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.2068 0.1585 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.2960 0.1580 sec/batch
# Nearest to more: russcol, unfalsifiable, moorcock, agitator, ethic, trismegistus, friend, barren,
# Nearest to with: meteorologists, modernized, tiberias, recht, vernon, infraction, scam, crested,
# Nearest to from: maternal, iced, away, ans, glissando, amphibole, pacifists, eqworld,
# Nearest to will: would, does, allow, might, you, guerrillas, ribbons, person,
# Nearest to by: staubach, food, cretans, mitzvah, genotype, affiliation, subotnick, csicop,
# Nearest to american: footballer, dodge, filmmaker, nigerian, sera, scams, jos, jason,
# Nearest to war: military, germany, troops, wars, ira, dominate, monophysites, volusia,
# Nearest to it: dharmakirti, curried, ocho, schiavo, hugs, testimonium, obe, reuniting,
# Nearest to accepted: prescriptions, reconstruction, humanitarian, hofstadter, mubarak, covenants, cease, slovenes,
# Nearest to woman: gandhara, niki, heater, hammurabi, idriss, father, mastered, friends,
# Nearest to scale: pounds, avail, diachronic, albion, pasquale, druidic, neuroleptic, feasible,
# Nearest to shown: indicate, pull, natures, lamentations, blunder, sacred, firefighting, gunning,
# Nearest to frac: infty, right, above, psi, linear, cdot, lct, where,
# Nearest to hold: caused, restrictive, ramirez, lind, steffi, introduces, past, usaf,
# Nearest to construction: fashion, bemba, ceiling, inflectional, sonnet, homegrown, firestorm, osprey,
# Nearest to notes: rockies, loeb, billboard, plotters, procurement, joschka, syntax, chorus,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.3281 0.1617 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.3204 0.1579 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.3192 0.1584 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.2722 0.1581 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.0521 0.1595 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.2844 0.1588 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.1769 0.1587 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.2893 0.1591 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.3149 0.1583 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.2005 0.1589 sec/batch
# Nearest to more: russcol, unfalsifiable, agitator, moorcock, ethic, trismegistus, friend, barren,
# Nearest to with: meteorologists, modernized, tiberias, recht, vernon, infraction, discovery, scam,
# Nearest to from: iced, maternal, away, ans, pacifists, glissando, amphibole, eqworld,
# Nearest to will: would, does, you, might, allow, no, ribbons, guerrillas,
# Nearest to by: staubach, food, genotype, cretans, mitzvah, affiliation, csicop, casino,
# Nearest to american: footballer, filmmaker, swimmer, nigerian, dodge, jos, jason, jr,
# Nearest to war: germany, military, troops, ii, battle, wars, monophysites, leaflet,
# Nearest to it: dharmakirti, ocho, curried, hugs, disgusting, schiavo, testimonium, obe,
# Nearest to accepted: reconstruction, prescriptions, humanitarian, hofstadter, mitanni, slovenes, covenants, posted,
# Nearest to woman: gandhara, niki, heater, father, adult, hammurabi, thousand, idriss,
# Nearest to scale: pounds, attenuation, albion, pasquale, avail, druidic, neuroleptic, diachronic,
# Nearest to shown: indicate, pull, lamentations, blunder, natures, gunning, hf, firefighting,
# Nearest to frac: right, infty, lct, cdot, above, psi, where, cos,
# Nearest to hold: caused, ramirez, restrictive, lind, steffi, telephoned, deterred, sweetness,
# Nearest to construction: bemba, ceiling, harbors, fashion, sonnet, inflectional, homegrown, osprey,
# Nearest to notes: rockies, syntax, inventions, plotters, loeb, billboard, joschka, chorus,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.2893 0.1619 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.2988 0.1587 sec/batch
# Epoch 2/10 Iteration: 9300 Avg. Training loss: 4.3059 0.0685 sec/batch
# Epoch 2/10 Iteration: 9400 Avg. Training loss: 4.2105 0.1587 sec/batch
# Epoch 2/10 Iteration: 9500 Avg. Training loss: 4.2555 0.1593 sec/batch
# Epoch 2/10 Iteration: 9600 Avg. Training loss: 4.1716 0.1590 sec/batch
# Epoch 2/10 Iteration: 9700 Avg. Training loss: 4.1841 0.1590 sec/batch
# Epoch 2/10 Iteration: 9800 Avg. Training loss: 4.1583 0.1587 sec/batch
# Epoch 2/10 Iteration: 9900 Avg. Training loss: 4.1237 0.1585 sec/batch
# Epoch 2/10 Iteration: 10000 Avg. Training loss: 4.2075 0.1603 sec/batch
# Nearest to more: russcol, unfalsifiable, agitator, moorcock, ethic, friend, trismegistus, barren,
# Nearest to with: meteorologists, modernized, tiberias, recht, vernon, intermediate, infraction, crested,
# Nearest to from: iced, maternal, away, ans, pacifists, amphibole, glissando, eqworld,
# Nearest to will: would, does, you, might, allow, unable, ribbons, no,
# Nearest to by: staubach, food, genotype, mitzvah, cretans, affiliation, csicop, tu,
# Nearest to american: footballer, nigerian, filmmaker, dodge, swimmer, spooner, jason, sera,
# Nearest to war: germany, troops, military, battle, prisoners, ii, wars, monophysites,
# Nearest to it: dharmakirti, ocho, curried, obe, disgusting, testimonium, schiavo, hugs,
# Nearest to accepted: prescriptions, humanitarian, mitanni, reconstruction, toomer, slovenes, covenants, hofstadter,
# Nearest to woman: gandhara, niki, father, adult, friends, heater, bagpipes, her,
# Nearest to scale: pounds, albion, antibiotics, attenuation, pasquale, responds, diachronic, neuroleptic,
# Nearest to shown: indicate, lamentations, pull, gunning, firefighting, natures, ugarit, sacred,
# Nearest to frac: right, infty, lct, cdot, psi, cos, above, linear,
# Nearest to hold: caused, restrictive, ramirez, move, steffi, lind, telephoned, naghten,
# Nearest to construction: bemba, inflectional, harbors, homegrown, fashion, ceiling, ridges, sonnet,
# Nearest to notes: rockies, loeb, syntax, joschka, plotters, inventions, chorus, cac,
# Epoch 2/10 Iteration: 10100 Avg. Training loss: 4.1816 0.1618 sec/batch
# Epoch 2/10 Iteration: 10200 Avg. Training loss: 4.1613 0.1576 sec/batch
# Epoch 2/10 Iteration: 10300 Avg. Training loss: 4.1880 0.1573 sec/batch
# Epoch 2/10 Iteration: 10400 Avg. Training loss: 4.1986 0.1586 sec/batch
# Epoch 2/10 Iteration: 10500 Avg. Training loss: 4.1769 0.1570 sec/batch
# Epoch 2/10 Iteration: 10600 Avg. Training loss: 4.0244 0.1573 sec/batch
# Epoch 2/10 Iteration: 10700 Avg. Training loss: 4.2137 0.1578 sec/batch
# Epoch 2/10 Iteration: 10800 Avg. Training loss: 4.2313 0.1588 sec/batch
# Epoch 2/10 Iteration: 10900 Avg. Training loss: 4.1837 0.1568 sec/batch
# Epoch 2/10 Iteration: 11000 Avg. Training loss: 4.2094 0.1574 sec/batch
# Nearest to more: russcol, unfalsifiable, agitator, moorcock, friend, ethic, barren, trismegistus,
# Nearest to with: meteorologists, modernized, tiberias, recht, vernon, intermediate, crested, tir,
# Nearest to from: iced, maternal, away, ans, pacifists, amphibole, glissando, eqworld,
# Nearest to will: would, does, you, might, allow, guerrillas, ribbons, unable,
# Nearest to by: staubach, food, genotype, affiliation, cretans, mitzvah, csicop, tu,
# Nearest to american: footballer, nigerian, dodge, filmmaker, swimmer, spooner, sera, dougherty,
# Nearest to war: troops, military, battle, germany, prisoners, wars, fighting, ii,
# Nearest to it: dharmakirti, ocho, curried, reuniting, obe, disgusting, testimonium, schiavo,
# Nearest to accepted: covenants, prescriptions, mitanni, toomer, slovenes, humanitarian, converts, hofstadter,
# Nearest to woman: gandhara, adult, father, niki, heater, her, seemingly, marry,
# Nearest to scale: albion, pounds, pasquale, neuroleptic, attenuation, antibiotics, kaist, avail,
# Nearest to shown: indicate, gunning, pull, lamentations, natures, ugarit, sacred, firefighting,
# Nearest to frac: infty, right, lct, psi, cdot, cos, linear, above,
# Nearest to hold: caused, ramirez, telephoned, move, steffi, restrictive, lind, naghten,
# Nearest to construction: bemba, ceiling, inflectional, ridges, harbors, sonnet, fashion, firestorm,
# Nearest to notes: rockies, loeb, billboard, syntax, chorus, joschka, inventions, plotters,
# Epoch 2/10 Iteration: 11100 Avg. Training loss: 4.2075 0.1701 sec/batch
# Epoch 2/10 Iteration: 11200 Avg. Training loss: 4.1792 0.1704 sec/batch
# Epoch 2/10 Iteration: 11300 Avg. Training loss: 4.2007 0.1699 sec/batch
# Epoch 2/10 Iteration: 11400 Avg. Training loss: 4.0923 0.1633 sec/batch
# Epoch 2/10 Iteration: 11500 Avg. Training loss: 4.0493 0.1641 sec/batch
# Epoch 2/10 Iteration: 11600 Avg. Training loss: 4.0912 0.1710 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 4.1252 0.1619 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.1347 0.1682 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.1494 0.1692 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.0701 0.1624 sec/batch
# Nearest to more: russcol, unfalsifiable, moorcock, agitator, ethic, friend, barren, trismegistus,
# Nearest to with: meteorologists, tiberias, modernized, recht, vernon, crested, tir, scam,
# Nearest to from: iced, away, maternal, ans, amphibole, pacifists, glissando, staunchest,
# Nearest to will: would, does, you, ribbons, might, guerrillas, unable, allow,
# Nearest to by: staubach, food, genotype, affiliation, cretans, mitzvah, incorrect, csicop,
# Nearest to american: footballer, nigerian, spooner, dodge, dougherty, sera, jabberwock, taciturn,
# Nearest to war: military, troops, prisoners, battle, germany, wars, ii, monophysites,
# Nearest to it: dharmakirti, ocho, obe, curried, reuniting, disgusting, testimonium, hugs,
# Nearest to accepted: prescriptions, mitanni, covenants, hofstadter, toomer, basrah, slovenes, forthcoming,
# Nearest to woman: adult, gandhara, niki, father, marry, heater, her, thousand,
# Nearest to scale: pounds, albion, attenuation, neuroleptic, antibiotics, pasquale, kaist, usefully,
# Nearest to shown: indicate, lamentations, gunning, pull, natures, sacred, ugarit, firefighting,
# Nearest to frac: right, infty, cdot, cos, mbox, psi, lct, quad,
# Nearest to hold: ramirez, telephoned, naghten, caused, lind, yeltsin, steffi, move,
# Nearest to construction: bemba, inflectional, harbors, ridges, ceiling, fashion, sonnet, firestorm,
# Nearest to notes: rockies, syntax, inventions, loeb, joschka, billboard, halmos, chorus,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.1607 0.1621 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.1920 0.1619 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.1617 0.1634 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.1345 0.1690 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.1160 0.1706 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.2044 0.1800 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.0865 0.1734 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.1408 0.1857 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.1141 0.1656 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.1515 0.1693 sec/batch
# Nearest to more: russcol, unfalsifiable, moorcock, agitator, barren, ethic, owls, friend,
# Nearest to with: meteorologists, tiberias, modernized, recht, vernon, tir, intermediate, sweden,
# Nearest to from: iced, maternal, away, ans, amphibole, glissando, pacifists, staunchest,
# Nearest to will: would, does, you, guerrillas, might, ribbons, allow, couldn,
# Nearest to by: food, genotype, staubach, cretans, affiliation, mitzvah, incorrect, csicop,
# Nearest to american: footballer, nigerian, filmmaker, swimmer, spooner, ryan, jason, armstrong,
# Nearest to war: military, troops, germany, prisoners, leaflet, ii, whitaker, battle,
# Nearest to it: dharmakirti, ocho, reuniting, disgusting, obe, curried, testimonium, hugs,
# Nearest to accepted: covenants, prescriptions, mitanni, basrah, toomer, slovenes, reconstruction, hofstadter,
# Nearest to woman: adult, niki, gandhara, father, marry, her, heater, man,
# Nearest to scale: pounds, attenuation, albion, pasquale, neuroleptic, least, antibiotics, sheltering,
# Nearest to shown: indicate, gunning, ugarit, lamentations, dragon, sacred, pull, blunder,
# Nearest to frac: right, infty, cdot, cos, mbox, psi, lct, quad,
# Nearest to hold: telephoned, ramirez, naghten, yeltsin, lind, move, steffi, introduces,
# Nearest to construction: bemba, inflectional, ridges, ceiling, fashion, sonnet, osprey, harbors,
# Nearest to notes: rockies, loeb, joschka, billboard, chorus, halmos, inventions, ominously,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.1714 0.1631 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.1398 0.1612 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.0095 0.1873 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.1325 0.1809 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.0940 0.1602 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.1303 0.1749 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.1118 0.1885 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.1542 0.1726 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.0525 0.1597 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.0874 0.1586 sec/batch
# Nearest to more: russcol, unfalsifiable, moorcock, agitator, barren, ethic, owls, friend,
# Nearest to with: meteorologists, tiberias, modernized, recht, vernon, tir, crested, scam,
# Nearest to from: iced, maternal, away, ans, amphibole, glissando, pacifists, staunchest,
# Nearest to will: would, does, you, guerrillas, ribbons, allow, might, unable,
# Nearest to by: staubach, genotype, food, cretans, affiliation, mitzvah, hydrocarbon, subotnick,
# Nearest to american: footballer, nigerian, spooner, swimmer, dodge, armstrong, jabberwock, dougherty,
# Nearest to war: ii, prisoners, germany, military, leaflet, wars, troops, battle,
# Nearest to it: disgusting, dharmakirti, obe, ocho, reuniting, curried, testimonium, hugs,
# Nearest to accepted: covenants, prescriptions, mitanni, reconstruction, slovenes, hofstadter, basrah, toomer,
# Nearest to woman: adult, niki, gandhara, marry, heater, father, fertility, bagpipes,
# Nearest to scale: albion, pounds, attenuation, popularized, neuroleptic, kaist, pasquale, least,
# Nearest to shown: indicate, ugarit, gunning, sacred, dragon, lamentations, pull, blunder,
# Nearest to frac: right, infty, cos, cdot, lct, mbox, quad, psi,
# Nearest to hold: telephoned, ramirez, yeltsin, move, naghten, steffi, lind, caused,
# Nearest to construction: bemba, inflectional, ridges, fashion, ceiling, sonnet, mouthpiece, frenzy,
# Nearest to notes: rockies, loeb, joschka, halmos, ominously, syntax, chorus, billboard,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.1277 0.1622 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.0650 0.1586 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.1265 0.1584 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.1359 0.1596 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.0517 0.1590 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.0510 0.1580 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.1218 0.1653 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.1004 0.1590 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.1831 0.1592 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.1253 0.1584 sec/batch
# Nearest to more: russcol, moorcock, agitator, unfalsifiable, ethic, barren, owls, friend,
# Nearest to with: tiberias, meteorologists, modernized, recht, vernon, tir, scam, crested,
# Nearest to from: iced, maternal, away, ans, amphibole, glissando, pacifists, staunchest,
# Nearest to will: would, does, you, ribbons, might, guerrillas, bellerophon, allow,
# Nearest to by: genotype, staubach, food, cretans, affiliation, mitzvah, incorrect, hydrocarbon,
# Nearest to american: footballer, spooner, nigerian, dodge, swimmer, armstrong, jabberwock, dougherty,
# Nearest to war: ii, troops, military, germany, prisoners, wars, battle, dominate,
# Nearest to it: obe, dharmakirti, ocho, reuniting, curried, testimonium, hugs, disgusting,
# Nearest to accepted: covenants, prescriptions, mitanni, slovenes, hofstadter, toomer, reconstruction, came,
# Nearest to woman: adult, gandhara, niki, fertility, children, marry, heater, bagpipes,
# Nearest to scale: albion, pounds, attenuation, least, exogenous, kaist, harwich, objecting,
# Nearest to shown: indicate, ugarit, dragon, lamentations, blunder, gunning, sacred, ribeira,
# Nearest to frac: infty, right, cos, cdot, lct, mbox, psi, quad,
# Nearest to hold: telephoned, ramirez, move, steffi, naghten, deterred, yeltsin, panzer,
# Nearest to construction: bemba, ridges, inflectional, frenzy, osprey, harbors, firestorm, fashion,
# Nearest to notes: syntax, rockies, loeb, chorus, joschka, halmos, ominously, bulmer,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.0551 0.1632 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.1431 0.1587 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.1034 0.1591 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.1145 0.1583 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.1323 0.1581 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.1396 0.1582 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.0900 0.1595 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 3.9940 0.1586 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.0458 0.1594 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.0961 0.1584 sec/batch
# Nearest to more: russcol, moorcock, agitator, unfalsifiable, ethic, owls, friend, barren,
# Nearest to with: tiberias, meteorologists, modernized, recht, vernon, scam, tir, intermediate,
# Nearest to from: iced, away, maternal, ans, amphibole, pacifists, glissando, staunchest,
# Nearest to will: would, does, you, ribbons, allow, might, sought, bellerophon,
# Nearest to by: genotype, staubach, food, affiliation, cretans, mitzvah, incorrect, tu,
# Nearest to american: footballer, nigerian, spooner, dodge, dougherty, jabberwock, sera, taciturn,
# Nearest to war: ii, wars, germany, dominate, military, ferdinand, troops, prisoners,
# Nearest to it: obe, dharmakirti, ocho, reuniting, curried, testimonium, disgusting, hugs,
# Nearest to accepted: prescriptions, mitanni, covenants, slovenes, came, toomer, reconstruction, mubarak,
# Nearest to woman: adult, niki, gandhara, fertility, children, heater, bagpipes, marry,
# Nearest to scale: pounds, albion, popularized, least, kaist, neuroleptic, pasquale, transitions,
# Nearest to shown: indicate, dragon, ugarit, gunning, blunder, sacred, lamentations, ribeira,
# Nearest to frac: infty, right, cos, cdot, psi, mbox, quad, lct,
# Nearest to hold: telephoned, ramirez, move, steffi, panzer, naghten, deterred, yeltsin,
# Nearest to construction: bemba, ridges, building, harbors, reincarnations, inflectional, osprey, homegrown,
# Nearest to notes: syntax, rockies, halmos, loeb, chorus, ominously, inventions, graeci,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.0507 0.1617 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.0849 0.1588 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 3.8972 0.1581 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 3.9718 0.1584 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.0454 0.1586 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.1516 0.1653 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.1008 0.1636 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.2042 0.1620 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.2099 0.1728 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.1421 0.1638 sec/batch
# Nearest to more: russcol, moorcock, agitator, unfalsifiable, ethic, owls, friend, barren,
# Nearest to with: meteorologists, tiberias, recht, modernized, vernon, scam, tir, intermediate,
# Nearest to from: iced, maternal, ans, away, amphibole, pacifists, glissando, staunchest,
# Nearest to will: would, does, you, allow, ribbons, might, bellerophon, sought,
# Nearest to by: genotype, staubach, food, affiliation, cretans, mitzvah, koffice, incorrect,
# Nearest to american: footballer, nigerian, swimmer, spooner, dodge, armstrong, sera, dougherty,
# Nearest to war: ii, troops, germany, wars, ferdinand, battle, leaflet, dominate,
# Nearest to it: dharmakirti, obe, ocho, schiavo, curried, annales, reuniting, disgusting,
# Nearest to accepted: prescriptions, covenants, mitanni, toomer, hofstadter, slovenes, mubarak, basrah,
# Nearest to woman: adult, niki, gandhara, fertility, heater, bagpipes, seemingly, marry,
# Nearest to scale: albion, pounds, popularized, pasquale, kaist, least, ibanez, neuroleptic,
# Nearest to shown: indicate, ugarit, dragon, sacred, blunder, gunning, lamentations, leader,
# Nearest to frac: infty, right, cdot, cos, psi, mbox, quad, lim,
# Nearest to hold: ramirez, telephoned, move, naghten, panzer, steffi, logique, almoravid,
# Nearest to construction: bemba, ridges, reincarnations, building, osprey, homegrown, harbors, mouthpiece,
# Nearest to notes: rockies, syntax, chorus, halmos, loeb, joschka, ominously, graeci,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 3.9446 0.1724 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.1058 0.1623 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.0767 0.1683 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.1019 0.1762 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.1389 0.1731 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.0756 0.1647 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 3.9197 0.1648 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 3.9601 0.1711 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.0863 0.1772 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 3.9981 0.1677 sec/batch
# Nearest to more: russcol, moorcock, agitator, unfalsifiable, owls, ethic, friend, barren,
# Nearest to with: meteorologists, tiberias, modernized, vernon, recht, intermediate, scam, tir,
# Nearest to from: iced, maternal, away, ans, amphibole, pacifists, glissando, staunchest,
# Nearest to will: would, does, you, bellerophon, might, allow, couldn, ribbons,
# Nearest to by: genotype, staubach, affiliation, cretans, food, mitzvah, hydrocarbon, tu,
# Nearest to american: footballer, swimmer, spooner, nigerian, mexican, dodge, dumas, filmmaker,
# Nearest to war: ii, germany, battle, troops, world, ferdinand, wars, leaflet,
# Nearest to it: obe, ocho, dharmakirti, annales, schiavo, curried, africaine, lass,
# Nearest to accepted: prescriptions, covenants, slovenes, toomer, mitanni, came, mubarak, hofstadter,
# Nearest to woman: adult, fertility, niki, gandhara, children, heater, bagpipes, marry,
# Nearest to scale: popularized, pounds, attenuation, least, albion, pasquale, exogenous, generalization,
# Nearest to shown: indicate, dragon, ugarit, gunning, summarized, lamentations, mathcal, blunder,
# Nearest to frac: right, infty, cos, cdot, mbox, psi, quad, lim,
# Nearest to hold: ramirez, move, telephoned, naghten, logique, panzer, lind, deterred,
# Nearest to construction: bemba, ridges, building, reincarnations, canals, homegrown, harbors, mouthpiece,
# Nearest to notes: rockies, syntax, halmos, joschka, ominously, graeci, loeb, bulmer,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.0949 0.1812 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.0316 0.1704 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.0436 0.1713 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.0780 0.1782 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.1617 0.1685 sec/batch
# Epoch 3/10 Iteration: 18600 Avg. Training loss: 4.1196 0.1656 sec/batch
# Epoch 3/10 Iteration: 18700 Avg. Training loss: 4.0370 0.1801 sec/batch
# Epoch 3/10 Iteration: 18800 Avg. Training loss: 4.0691 0.1753 sec/batch
# Epoch 3/10 Iteration: 18900 Avg. Training loss: 3.9851 0.1631 sec/batch
# Epoch 3/10 Iteration: 19000 Avg. Training loss: 4.0329 0.1625 sec/batch
# Nearest to more: russcol, moorcock, agitator, owls, unfalsifiable, ethic, friend, barren,
# Nearest to with: meteorologists, modernized, tiberias, vernon, recht, tir, scam, intermediate,
# Nearest to from: maternal, iced, away, ans, amphibole, staunchest, pacifists, glissando,
# Nearest to will: would, does, you, sought, try, ribbons, couldn, bellerophon,
# Nearest to by: genotype, staubach, food, cretans, affiliation, hydrocarbon, mitzvah, tu,
# Nearest to american: footballer, nigerian, swimmer, spooner, dougherty, taciturn, dramatists, mexican,
# Nearest to war: ii, leaflet, battle, germany, troops, wars, coups, prisoners,
# Nearest to it: obe, ocho, dharmakirti, disgusting, schiavo, lass, curried, africaine,
# Nearest to accepted: prescriptions, covenants, mitanni, toomer, observed, mubarak, slovenes, came,
# Nearest to woman: adult, gandhara, fertility, niki, marry, heater, bagpipes, mannlicher,
# Nearest to scale: albion, pounds, pasquale, generalization, least, popularized, exogenous, transitions,
# Nearest to shown: indicate, dragon, ugarit, lamentations, gunning, quantized, innumerable, sacred,
# Nearest to frac: right, infty, cos, cdot, psi, mbox, quad, lim,
# Nearest to hold: telephoned, move, logique, panzer, naghten, ramirez, steffi, deterred,
# Nearest to construction: bemba, ridges, building, canals, reincarnations, homegrown, harbors, osprey,
# Nearest to notes: rockies, syntax, bulmer, joschka, graeci, loeb, cac, ominously,
# Epoch 3/10 Iteration: 19100 Avg. Training loss: 3.9633 0.1632 sec/batch
# Epoch 3/10 Iteration: 19200 Avg. Training loss: 4.0369 0.1637 sec/batch
# Epoch 3/10 Iteration: 19300 Avg. Training loss: 4.0184 0.1595 sec/batch
# Epoch 3/10 Iteration: 19400 Avg. Training loss: 4.0024 0.1655 sec/batch
# Epoch 3/10 Iteration: 19500 Avg. Training loss: 4.0435 0.1673 sec/batch
# Epoch 3/10 Iteration: 19600 Avg. Training loss: 4.0214 0.1591 sec/batch
# Epoch 3/10 Iteration: 19700 Avg. Training loss: 4.0377 0.1606 sec/batch
# Epoch 3/10 Iteration: 19800 Avg. Training loss: 4.0315 0.1627 sec/batch
# Epoch 3/10 Iteration: 19900 Avg. Training loss: 3.8965 0.1576 sec/batch
# Epoch 3/10 Iteration: 20000 Avg. Training loss: 4.0631 0.1592 sec/batch
# Nearest to more: russcol, moorcock, agitator, owls, unfalsifiable, ethic, friend, barren,
# Nearest to with: meteorologists, tiberias, modernized, vernon, recht, tir, intermediate, scam,
# Nearest to from: maternal, iced, away, amphibole, ans, staunchest, pacifists, fathered,
# Nearest to will: would, does, sought, you, ribbons, allow, bellerophon, try,
# Nearest to by: genotype, staubach, food, cretans, affiliation, oxidant, hydrocarbon, mitzvah,
# Nearest to american: footballer, nigerian, spooner, swimmer, taciturn, dougherty, puerto, glorification,
# Nearest to war: ii, battle, wars, troops, ferdinand, world, germany, prisoners,
# Nearest to it: obe, ocho, disgusting, dharmakirti, schiavo, lass, reuniting, curried,
# Nearest to accepted: prescriptions, covenants, mitanni, observed, toomer, reminder, mubarak, slovenes,
# Nearest to woman: adult, gandhara, fertility, marry, man, niki, heater, mannlicher,
# Nearest to scale: albion, least, pasquale, pounds, generalization, popularized, exogenous, transitions,
# Nearest to shown: indicate, ugarit, dragon, gunning, lamentations, sacred, summarized, quantized,
# Nearest to frac: right, infty, cos, cdot, mbox, psi, quad, lim,
# Nearest to hold: telephoned, logique, move, naghten, panzer, steffi, ramirez, deterred,
# Nearest to construction: building, bemba, ridges, reincarnations, canals, homegrown, osprey, fashion,
# Nearest to notes: rockies, graeci, chorus, syntax, ominously, bulmer, joschka, loeb,
# Epoch 3/10 Iteration: 20100 Avg. Training loss: 4.0645 0.1726 sec/batch
# Epoch 3/10 Iteration: 20200 Avg. Training loss: 4.0712 0.1675 sec/batch
# Epoch 3/10 Iteration: 20300 Avg. Training loss: 4.0670 0.1703 sec/batch
# Epoch 3/10 Iteration: 20400 Avg. Training loss: 4.0798 0.1748 sec/batch
# Epoch 3/10 Iteration: 20500 Avg. Training loss: 4.0483 0.1622 sec/batch
# Epoch 3/10 Iteration: 20600 Avg. Training loss: 4.0188 0.1753 sec/batch
# Epoch 3/10 Iteration: 20700 Avg. Training loss: 3.9959 0.1688 sec/batch
# Epoch 3/10 Iteration: 20800 Avg. Training loss: 3.8347 0.1636 sec/batch
# Epoch 3/10 Iteration: 20900 Avg. Training loss: 4.0371 0.1610 sec/batch
# Epoch 3/10 Iteration: 21000 Avg. Training loss: 4.0037 0.1613 sec/batch
# Nearest to more: russcol, moorcock, agitator, owls, unfalsifiable, ethic, friend, barren,
# Nearest to with: meteorologists, tiberias, modernized, vernon, recht, tir, intermediate, crested,
# Nearest to from: iced, maternal, amphibole, away, staunchest, ans, pacifists, recognize,
# Nearest to will: would, does, ribbons, you, shrink, allow, couldn, try,
# Nearest to by: genotype, staubach, food, affiliation, cretans, oxidant, hydrocarbon, tu,
# Nearest to american: nigerian, spooner, footballer, taciturn, dougherty, lha, unido, glorification,
# Nearest to war: ii, wars, ferdinand, battle, troops, prisoners, germany, world,
# Nearest to it: obe, ocho, disgusting, dharmakirti, reuniting, lass, paulo, curried,
# Nearest to accepted: prescriptions, covenants, mitanni, observed, mubarak, toomer, came, reminder,
# Nearest to woman: adult, fertility, gandhara, marry, niki, man, heater, mannlicher,
# Nearest to scale: albion, pasquale, least, popularized, generalization, transitions, pounds, kaist,
# Nearest to shown: indicate, ugarit, dragon, gunning, lamentations, sacred, summarized, quantized,
# Nearest to frac: right, infty, cos, cdot, psi, mbox, left, quad,
# Nearest to hold: telephoned, logique, naghten, move, panzer, ramirez, lind, steffi,
# Nearest to construction: building, bemba, ridges, canals, homegrown, reincarnations, fashion, mouthpiece,
# Nearest to notes: rockies, bulmer, graeci, syntax, ominously, joschka, halmos, chorus,
# Epoch 3/10 Iteration: 21100 Avg. Training loss: 3.9763 0.1775 sec/batch
# Epoch 3/10 Iteration: 21200 Avg. Training loss: 4.0041 0.1696 sec/batch
# Epoch 3/10 Iteration: 21300 Avg. Training loss: 3.9038 0.1624 sec/batch
# Epoch 3/10 Iteration: 21400 Avg. Training loss: 4.0398 0.1605 sec/batch
# Epoch 3/10 Iteration: 21500 Avg. Training loss: 4.0608 0.1588 sec/batch
# Epoch 3/10 Iteration: 21600 Avg. Training loss: 4.0339 0.1602 sec/batch
# Epoch 3/10 Iteration: 21700 Avg. Training loss: 4.0365 0.1649 sec/batch
# Epoch 3/10 Iteration: 21800 Avg. Training loss: 4.0408 0.1646 sec/batch
# Epoch 3/10 Iteration: 21900 Avg. Training loss: 4.0085 0.1588 sec/batch
# Epoch 3/10 Iteration: 22000 Avg. Training loss: 3.9948 0.1595 sec/batch
# Nearest to more: russcol, moorcock, agitator, owls, unfalsifiable, friend, ethic, barren,
# Nearest to with: meteorologists, tiberias, vernon, modernized, recht, tir, scam, fantasy,
# Nearest to from: iced, maternal, amphibole, ans, staunchest, away, pacifists, recognize,
# Nearest to will: would, does, ribbons, you, couldn, try, shrink, allow,
# Nearest to by: genotype, staubach, food, affiliation, cretans, oxidant, tu, holiness,
# Nearest to american: spooner, nigerian, footballer, taciturn, dougherty, swimmer, lha, choctaw,
# Nearest to war: ii, wars, prisoners, world, battle, troops, germany, dominate,
# Nearest to it: obe, ocho, disgusting, reuniting, lass, dharmakirti, schiavo, paulo,
# Nearest to accepted: prescriptions, covenants, mitanni, observed, toomer, mubarak, forthcoming, basrah,
# Nearest to woman: adult, fertility, marry, man, niki, gandhara, children, bagpipes,
# Nearest to scale: albion, transitions, pasquale, popularized, least, generalization, pounds, kaist,
# Nearest to shown: indicate, ugarit, gunning, lamentations, dragon, summarized, sacred, leader,
# Nearest to frac: right, infty, cos, cdot, mbox, left, psi, omega,
# Nearest to hold: telephoned, logique, panzer, lind, move, naghten, steffi, ramirez,
# Nearest to construction: building, bemba, ridges, canals, homegrown, fashion, reincarnations, mouthpiece,
# Nearest to notes: graeci, rockies, bulmer, ominously, syntax, chorus, loeb, halmos,
# Epoch 3/10 Iteration: 22100 Avg. Training loss: 4.0013 0.1617 sec/batch
# Epoch 3/10 Iteration: 22200 Avg. Training loss: 4.0245 0.1589 sec/batch
# Epoch 3/10 Iteration: 22300 Avg. Training loss: 4.0407 0.1858 sec/batch
# Epoch 3/10 Iteration: 22400 Avg. Training loss: 4.0634 0.1639 sec/batch
# Epoch 3/10 Iteration: 22500 Avg. Training loss: 3.9945 0.1623 sec/batch
# ...
# Nearest to woman: fertility, man, inquiring, gynaecology, pacifica, steamy, castration, desecration,
# Nearest to scale: scales, freedoms, notes, renegade, yg, inversion, generalization, privation,
# Nearest to shown: shows, appear, ugarit, indicate, showing, leads, summarized, listed,
# Nearest to frac: cos, contempt, cdot, colorings, mouvement, right, kpa, lag,
# Nearest to hold: holds, held, offering, holding, noc, move, amenities, pulled,
# Nearest to construction: building, planned, courtyards, shortage, construct, plans, masque, mouthpiece,
# Nearest to notes: note, clef, scale, scales, harmonics, weisstein, diatonic, gambia,
# Epoch 10/10 Iteration: 85100 Avg. Training loss: 3.8600 0.1707 sec/batch
# Epoch 10/10 Iteration: 85200 Avg. Training loss: 3.8643 0.1732 sec/batch
# Epoch 10/10 Iteration: 85300 Avg. Training loss: 3.8957 0.1712 sec/batch
# Epoch 10/10 Iteration: 85400 Avg. Training loss: 3.8102 0.1683 sec/batch
# Epoch 10/10 Iteration: 85500 Avg. Training loss: 3.8197 0.1694 sec/batch
# Epoch 10/10 Iteration: 85600 Avg. Training loss: 3.6140 0.1704 sec/batch
# Epoch 10/10 Iteration: 85700 Avg. Training loss: 3.8250 0.1619 sec/batch
# Epoch 10/10 Iteration: 85800 Avg. Training loss: 3.8165 0.1642 sec/batch
# Epoch 10/10 Iteration: 85900 Avg. Training loss: 3.8243 0.1849 sec/batch
# Epoch 10/10 Iteration: 86000 Avg. Training loss: 3.8244 0.1812 sec/batch
# Nearest to more: russcol, owls, moorcock, presses, espero, ethic, francione, earless,
# Nearest to with: boarded, facilitates, modernized, vernon, crested, franchised, norodom, tiberias,
# Nearest to from: ans, elaborated, canyon, unbelievable, irulan, recognize, matre, amphibole,
# Nearest to will: would, expected, does, must, ll, vowed, shall, try,
# Nearest to by: holiness, genotype, affiliation, tyrant, bogor, oxidant, mays, alga,
# Nearest to american: america, gammon, professional, glorification, birkhoff, aftereffects, airs, african,
# Nearest to war: world, wars, ii, provers, machinima, ww, novarum, opioids,
# Nearest to it: nzd, disgusting, dodd, schiavo, misc, rich, suggest, documenting,
# Nearest to accepted: accept, accepts, predicted, mubarak, victor, stubbornly, observed, proposed,
# Nearest to woman: fertility, man, inquiring, gynaecology, steamy, pacifica, children, adult,
# Nearest to scale: freedoms, scales, renegade, notes, yg, privation, grandees, inversion,
# Nearest to shown: shows, appear, leads, ugarit, showing, indicate, show, meddle,
# Nearest to frac: cos, contempt, right, cdot, mouvement, kpa, colorings, lag,
# Nearest to hold: holds, held, holding, offering, noc, amenities, take, move,
# Nearest to construction: building, courtyards, planned, plans, architectural, lattice, reincarnations, shortage,
# Nearest to notes: note, clef, scales, scale, harmonics, mascheroni, weisstein, gambia,
# Epoch 10/10 Iteration: 86100 Avg. Training loss: 3.6913 0.1884 sec/batch
# Epoch 10/10 Iteration: 86200 Avg. Training loss: 3.8489 0.1794 sec/batch
# Epoch 10/10 Iteration: 86300 Avg. Training loss: 3.8489 0.1691 sec/batch
# Epoch 10/10 Iteration: 86400 Avg. Training loss: 3.8475 0.1600 sec/batch
# Epoch 10/10 Iteration: 86500 Avg. Training loss: 3.8579 0.1688 sec/batch
# Epoch 10/10 Iteration: 86600 Avg. Training loss: 3.8860 0.1664 sec/batch
# Epoch 10/10 Iteration: 86700 Avg. Training loss: 3.8144 0.1615 sec/batch
# Epoch 10/10 Iteration: 86800 Avg. Training loss: 3.8372 0.1638 sec/batch
# Epoch 10/10 Iteration: 86900 Avg. Training loss: 3.7869 0.1686 sec/batch
# Epoch 10/10 Iteration: 87000 Avg. Training loss: 3.8435 0.1670 sec/batch
# Nearest to more: russcol, owls, moorcock, presses, espero, ethic, comix, francione,
# Nearest to with: boarded, facilitates, modernized, vernon, crested, franchised, norodom, tiberias,
# Nearest to from: ans, canyon, elaborated, irulan, unbelievable, amphibole, matre, conceptual,
# Nearest to will: would, expected, does, ll, must, you, shall, vowed,
# Nearest to by: holiness, genotype, affiliation, bogor, oxidant, tyrant, mays, alga,
# Nearest to american: gammon, professional, german, british, america, birkhoff, serling, french,
# Nearest to war: world, wars, ii, opioids, machinima, allies, provers, veterans,
# Nearest to it: nzd, disgusting, schiavo, dodd, misc, anthropologist, rich, curried,
# Nearest to accepted: accept, accepts, mubarak, stubbornly, proposed, universally, proposal, predicted,
# Nearest to woman: fertility, man, inquiring, gynaecology, steamy, pacifica, conte, eduardo,
# Nearest to scale: freedoms, scales, notes, renegade, yg, generalization, inversion, privation,
# Nearest to shown: shows, appear, indicate, ugarit, leads, showing, show, clearly,
# Nearest to frac: cos, right, contempt, cdot, kpa, mouvement, janssen, cabaret,
# Nearest to hold: holds, held, holding, offering, noc, amenities, move, pulled,
# Nearest to construction: building, courtyards, construct, planned, architectural, plans, reincarnations, mouthpiece,
# Nearest to notes: note, clef, scale, scales, harmonics, mascheroni, weisstein, diatonic,
# Epoch 10/10 Iteration: 87100 Avg. Training loss: 3.8692 0.1729 sec/batch
# Epoch 10/10 Iteration: 87200 Avg. Training loss: 3.8853 0.1692 sec/batch
# Epoch 10/10 Iteration: 87300 Avg. Training loss: 3.8495 0.1745 sec/batch
# Epoch 10/10 Iteration: 87400 Avg. Training loss: 3.7749 0.1738 sec/batch
# Epoch 10/10 Iteration: 87500 Avg. Training loss: 3.7544 0.1663 sec/batch
# Epoch 10/10 Iteration: 87600 Avg. Training loss: 3.8865 0.1684 sec/batch
# Epoch 10/10 Iteration: 87700 Avg. Training loss: 3.8369 0.1763 sec/batch
# Epoch 10/10 Iteration: 87800 Avg. Training loss: 3.8297 0.1730 sec/batch
# Epoch 10/10 Iteration: 87900 Avg. Training loss: 3.7943 0.1667 sec/batch
# Epoch 10/10 Iteration: 88000 Avg. Training loss: 3.8172 0.1691 sec/batch
# Nearest to more: russcol, owls, moorcock, presses, espero, ethic, earless, comix,
# Nearest to with: boarded, facilitates, modernized, vernon, crested, franchised, norodom, tiberias,
# Nearest to from: elaborated, canyon, ans, irulan, unbelievable, amphibole, matre, maternal,
# Nearest to will: would, expected, ll, does, vowed, must, shall, tend,
# Nearest to by: holiness, genotype, affiliation, bogor, oxidant, alga, tyrant, mays,
# Nearest to american: america, german, gammon, birkhoff, ultrasonography, bookshelf, professional, british,
# Nearest to war: world, ii, wars, opioids, machinima, provers, ferdinand, goldfinger,
# Nearest to it: nzd, disgusting, schiavo, dodd, misc, curried, anthropologist, rich,
# Nearest to accepted: accept, accepts, proposed, proposal, mubarak, victor, stubbornly, rejected,
# Nearest to woman: fertility, man, steamy, inquiring, conte, gynaecology, eduardo, pacifica,
# Nearest to scale: scales, freedoms, renegade, notes, yg, generalization, inversion, logan,
# Nearest to shown: shows, appear, showing, clearly, leads, show, indicate, ugarit,
# Nearest to frac: cos, right, cdot, contempt, kpa, mouvement, cabaret, omega,
# Nearest to hold: holds, held, holding, offering, noc, amenities, move, pulled,
# Nearest to construction: building, courtyards, lattice, construct, architectural, planned, plans, reincarnations,
# Nearest to notes: note, scales, clef, scale, gambia, harmonics, mascheroni, diatonic,
# Epoch 10/10 Iteration: 88100 Avg. Training loss: 3.7855 0.1690 sec/batch
# Epoch 10/10 Iteration: 88200 Avg. Training loss: 3.8777 0.1730 sec/batch
# Epoch 10/10 Iteration: 88300 Avg. Training loss: 3.7205 0.1838 sec/batch
# Epoch 10/10 Iteration: 88400 Avg. Training loss: 3.8832 0.1751 sec/batch
# Epoch 10/10 Iteration: 88500 Avg. Training loss: 3.8076 0.1606 sec/batch
# Epoch 10/10 Iteration: 88600 Avg. Training loss: 3.7001 0.1742 sec/batch
# Epoch 10/10 Iteration: 88700 Avg. Training loss: 3.8622 0.1807 sec/batch
# Epoch 10/10 Iteration: 88800 Avg. Training loss: 3.8633 0.1652 sec/batch
# Epoch 10/10 Iteration: 88900 Avg. Training loss: 3.8559 0.1690 sec/batch
# Epoch 10/10 Iteration: 89000 Avg. Training loss: 3.8947 0.1744 sec/batch
# Nearest to more: russcol, owls, moorcock, presses, espero, ethic, earless, comix,
# Nearest to with: boarded, facilitates, modernized, vernon, franchised, norodom, crested, tiberias,
# Nearest to from: elaborated, canyon, ans, irulan, unbelievable, matre, conceptual, amphibole,
# Nearest to will: would, expected, ll, does, vowed, try, must, enough,
# Nearest to by: holiness, genotype, affiliation, bogor, oxidant, alga, mays, subotnick,
# Nearest to american: bookshelf, america, gammon, ultrasonography, birkhoff, glorification, professional, flatwater,
# Nearest to war: world, ii, wars, opioids, ferdinand, machinima, provers, novarum,
# Nearest to it: nzd, disgusting, schiavo, dodd, assumed, misc, documenting, rich,
# Nearest to accepted: accept, accepts, proposed, mubarak, predicted, proposal, stubbornly, observed,
# Nearest to woman: fertility, man, steamy, gynaecology, eduardo, inquiring, conte, children,
# Nearest to scale: scales, freedoms, renegade, notes, yg, large, kilotons, privation,
# Nearest to shown: shows, appear, indicate, clearly, ugarit, showing, leads, summarized,
# Nearest to frac: cos, cdot, contempt, right, janssen, kpa, mouvement, cabaret,
# Nearest to hold: holds, held, holding, offering, noc, amenities, move, pulled,
# Nearest to construction: building, courtyards, lattice, triangle, mouthpiece, construct, masque, shortage,
# Nearest to notes: note, clef, scales, harmonics, mascheroni, gambia, incoming, diatonic,
# Epoch 10/10 Iteration: 89100 Avg. Training loss: 3.7714 0.1723 sec/batch
# Epoch 10/10 Iteration: 89200 Avg. Training loss: 3.8773 0.1746 sec/batch
# Epoch 10/10 Iteration: 89300 Avg. Training loss: 3.8658 0.1715 sec/batch
# Epoch 10/10 Iteration: 89400 Avg. Training loss: 3.8257 0.1716 sec/batch
# Epoch 10/10 Iteration: 89500 Avg. Training loss: 3.8735 0.1686 sec/batch
# Epoch 10/10 Iteration: 89600 Avg. Training loss: 3.8210 0.1695 sec/batch
# Epoch 10/10 Iteration: 89700 Avg. Training loss: 3.8501 0.1743 sec/batch
# Epoch 10/10 Iteration: 89800 Avg. Training loss: 3.7215 0.1682 sec/batch
# Epoch 10/10 Iteration: 89900 Avg. Training loss: 3.8133 0.1771 sec/batch
# Epoch 10/10 Iteration: 90000 Avg. Training loss: 3.8234 0.1725 sec/batch
# Nearest to more: russcol, owls, moorcock, presses, espero, ethic, earless, comix,
# Nearest to with: boarded, facilitates, modernized, vernon, franchised, norodom, crested, foyle,
# Nearest to from: elaborated, ans, canyon, irulan, unbelievable, matre, conceptual, amphibole,
# Nearest to will: would, expected, ll, does, vowed, did, try, planned,
# Nearest to by: holiness, genotype, affiliation, bogor, oxidant, alga, subotnick, mays,
# Nearest to american: america, ultrasonography, bookshelf, professional, gammon, african, glorification, aftereffects,
# Nearest to war: world, wars, ii, conflict, opioids, fought, deg, ferdinand,
# Nearest to it: nzd, disgusting, schiavo, dodd, misc, documenting, assumed, rich,
# Nearest to accepted: accept, accepts, mubarak, proposed, proposal, universally, stubbornly, predicted,
# Nearest to woman: fertility, man, steamy, she, her, inquiring, gynaecology, conte,
# Nearest to scale: scales, freedoms, notes, renegade, yg, large, privation, autocannon,
# Nearest to shown: shows, appear, indicate, leads, showing, ugarit, clearly, listed,
# Nearest to frac: cos, contempt, cdot, right, janssen, kpa, mouvement, cabaret,
# Nearest to hold: holds, held, holding, offering, noc, amenities, take, applies,
# Nearest to construction: building, courtyards, plans, shortage, triangle, construct, planned, lattice,
# Nearest to notes: note, clef, scales, harmonics, scale, diatonic, mascheroni, incoming,
# Epoch 10/10 Iteration: 90100 Avg. Training loss: 3.8401 0.1662 sec/batch
# Epoch 10/10 Iteration: 90200 Avg. Training loss: 3.8353 0.1699 sec/batch
# Epoch 10/10 Iteration: 90300 Avg. Training loss: 3.7228 0.1731 sec/batch
# Epoch 10/10 Iteration: 90400 Avg. Training loss: 3.6375 0.1652 sec/batch
# Epoch 10/10 Iteration: 90500 Avg. Training loss: 3.7356 0.1653 sec/batch
# Epoch 10/10 Iteration: 90600 Avg. Training loss: 3.8563 0.1668 sec/batch
# Epoch 10/10 Iteration: 90700 Avg. Training loss: 3.9357 0.1612 sec/batch
# Epoch 10/10 Iteration: 90800 Avg. Training loss: 3.8526 0.1719 sec/batch
# Epoch 10/10 Iteration: 90900 Avg. Training loss: 3.9172 0.1657 sec/batch
# Epoch 10/10 Iteration: 91000 Avg. Training loss: 3.9285 0.1734 sec/batch
# Nearest to more: russcol, owls, moorcock, presses, espero, ethic, earless, comix,
# Nearest to with: boarded, facilitates, modernized, vernon, franchised, norodom, crested, intermediate,
# Nearest to from: elaborated, ans, canyon, irulan, unbelievable, matre, maternal, amphibole,
# Nearest to will: would, ll, expected, vowed, does, try, did, phineus,
# Nearest to by: holiness, genotype, affiliation, bogor, mays, alga, oxidant, subotnick,
# Nearest to american: gammon, america, glorification, professional, serling, designator, ultrasonography, bookshelf,
# Nearest to war: world, ii, wars, opioids, ww, veterans, provers, mig,
# Nearest to it: nzd, disgusting, schiavo, assumed, dodd, misc, rich, suggest,
# Nearest to accepted: accept, accepts, mubarak, proposal, stubbornly, proposed, victor, predicted,
# Nearest to woman: fertility, man, steamy, inquiring, conte, gynaecology, pacifica, solemnly,
# Nearest to scale: scales, freedoms, renegade, notes, yg, large, inversion, privation,
# Nearest to shown: shows, appear, ugarit, showing, meddle, indicate, leads, listed,
# Nearest to frac: cos, contempt, cdot, right, janssen, junichiro, kpa, mouvement,
# Nearest to hold: holds, held, holding, offering, noc, pulled, amenities, move,
# Nearest to construction: building, plans, shortage, courtyards, planned, construct, triangle, lattice,
# Nearest to notes: note, scales, clef, harmonics, incoming, diatonic, scale, gambia,
# Epoch 10/10 Iteration: 91100 Avg. Training loss: 3.8458 0.1776 sec/batch
# Epoch 10/10 Iteration: 91200 Avg. Training loss: 3.7080 0.1770 sec/batch
# Epoch 10/10 Iteration: 91300 Avg. Training loss: 3.8202 0.1685 sec/batch
# Epoch 10/10 Iteration: 91400 Avg. Training loss: 3.8162 0.1694 sec/batch
# Epoch 10/10 Iteration: 91500 Avg. Training loss: 3.7959 0.1672 sec/batch
# Epoch 10/10 Iteration: 91600 Avg. Training loss: 3.8494 0.1801 sec/batch
# Epoch 10/10 Iteration: 91700 Avg. Training loss: 3.8029 0.1699 sec/batch
# Epoch 10/10 Iteration: 91800 Avg. Training loss: 3.5544 0.1698 sec/batch
# Epoch 10/10 Iteration: 91900 Avg. Training loss: 3.8171 0.1660 sec/batch
# Epoch 10/10 Iteration: 92000 Avg. Training loss: 3.7683 0.1619 sec/batch
# Nearest to more: russcol, owls, moorcock, presses, espero, ethic, earless, comix,
# Nearest to with: boarded, facilitates, modernized, vernon, franchised, norodom, breathing, crested,
# Nearest to from: elaborated, ans, canyon, irulan, unbelievable, maternal, matre, amphibole,
# Nearest to will: would, expected, ll, does, vowed, planned, try, you,
# Nearest to by: holiness, genotype, affiliation, bogor, mays, alga, oxidant, subotnick,
# Nearest to american: german, british, french, gammon, english, serling, jr, canadian,
# Nearest to war: world, ii, wars, ww, ferdinand, ncaa, hammerstein, opioids,
# Nearest to it: nzd, dodd, schiavo, disgusting, misc, rich, suggest, assumed,
# Nearest to accepted: accept, accepts, mubarak, proposal, cerebrum, victor, stubbornly, controversial,
# Nearest to woman: fertility, steamy, man, children, gynaecology, eduardo, inquiring, pacifica,
# Nearest to scale: scales, freedoms, notes, large, renegade, yg, privation, inversion,
# Nearest to shown: shows, appear, showing, indicate, leads, meddle, clearly, listed,
# Nearest to frac: cos, contempt, right, janssen, cdot, junichiro, kpa, colorings,
# Nearest to hold: holds, held, holding, offering, noc, pulled, move, amenities,
# Nearest to construction: building, shortage, courtyards, plans, convent, construct, mouthpiece, constructed,
# Nearest to notes: note, scales, scale, harmonics, clef, incoming, nylon, diatonic,
# Epoch 10/10 Iteration: 92100 Avg. Training loss: 3.8318 0.1845 sec/batch
# Epoch 10/10 Iteration: 92200 Avg. Training loss: 3.8457 0.1765 sec/batch
# Epoch 10/10 Iteration: 92300 Avg. Training loss: 3.7767 0.1713 sec/batch
# Epoch 10/10 Iteration: 92400 Avg. Training loss: 3.8578 0.1718 sec/batch
# Epoch 10/10 Iteration: 92500 Avg. Training loss: 3.8418 0.1687 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
